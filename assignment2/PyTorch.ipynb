# %% [markdown]
# # Training a ConvNet PyTorch
#
# In this notebook, you'll learn how to use the powerful PyTorch framework to specify a conv net architecture and train it on the CIFAR-10 dataset.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import sampler

import torchvision.datasets as dset
import torchvision.transforms as T

import numpy as np

import timeit

# %% [markdown]
# ## What's this PyTorch business?
#
# You've written a lot of code in this assignment to provide a whole host of neural network functionality. Dropout, Batch Norm, and 2D convolutions are some of the workhorses of deep learning in computer vision. You've also worked hard to make your code efficient and vectorized.
#
# For the last part of this assignment, though, we're going to leave behind your beautiful codebase and instead migrate to one of two popular deep learning frameworks: in this instance, PyTorch (or TensorFlow, if you switch over to that notebook).
#
# Why?
#
# * Our code will now run on GPUs! Much faster training. When using a framework like PyTorch or TensorFlow you can harness the power of the GPU for your own custom neural network architectures without having to write CUDA code directly (which is beyond the scope of this class).
# * We want you to be ready to use one of these frameworks for your project so you can experiment more efficiently than if you were writing every feature you want to use by hand.
# * We want you to stand on the shoulders of giants! TensorFlow and PyTorch are both excellent frameworks that will make your lives a lot easier, and now that you understand their guts, you are free to use them :)
# * We want you to be exposed to the sort of deep learning code you might run into in academia or industry.

# %% [markdown]
# ## How will I learn PyTorch?
#
# If you've used Torch before, but are new to PyTorch, this tutorial might be of use: http://pytorch.org/tutorials/beginner/former_torchies_tutorial.html
#
# Otherwise, this notebook will walk you through much of what you need to do to train models in Torch. See the end of the notebook for some links to helpful tutorials if you want to learn more or need further clarification on topics that aren't fully explained here.

# %% [markdown]
# ## Load Datasets
#
# We load the CIFAR-10 dataset. This might take a couple minutes the first time you do it, but the files should stay cached after that.

# %%
class ChunkSampler(sampler.Sampler):
    """Samples elements sequentially from some offset. 
    Arguments:
        num_samples: # of desired datapoints
        start: offset where we should start selecting from
    """
    def __init__(self, num_samples, start = 0):
        self.num_samples = num_samples
        self.start = start

    def __iter__(self):
        return iter(range(self.start, self.start + self.num_samples))

    def __len__(self):
        return self.num_samples

NUM_TRAIN = 49000
NUM_VAL = 1000

cifar10_train = dset.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=T.ToTensor())
loader_train = DataLoader(cifar10_train, batch_size=64, sampler=ChunkSampler(NUM_TRAIN, 0))

cifar10_val = dset.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=T.ToTensor())
loader_val = DataLoader(cifar10_val, batch_size=64, sampler=ChunkSampler(NUM_VAL, NUM_TRAIN))

cifar10_test = dset.CIFAR10('./cs231n/datasets', train=False, download=True,
                          transform=T.ToTensor())
loader_test = DataLoader(cifar10_test, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# For now, we're going to use a CPU-friendly datatype. Later, we'll switch to a datatype that will move all our computations to the GPU and measure the speedup.

# %%
dtype = torch.FloatTensor # the CPU datatype

# Constant to control how frequently we print train loss
print_every = 100

# This is a little utility that we'll use to reset the model
# if we want to re-initialize all our parameters
def reset(m):
    if hasattr(m, 'reset_parameters'):
        m.reset_parameters()

# %% [markdown]
# ## Example Model
#
# ### Some assorted tidbits
#
# Let's start by looking at a simple model. First, note that PyTorch operates on Tensors, which are n-dimensional arrays functionally analogous to numpy's ndarrays, with the additional feature that they can be used for computations on GPUs.
#
# We'll provide you with a Flatten function, which we explain here. Remember that our image data (and more relevantly, our intermediate feature maps) are initially N x C x H x W, where:
# * N is the number of datapoints
# * C is the number of channels
# * H is the height of the intermediate feature map in pixels
# * W is the height of the intermediate feature map in pixels
#
# This is the right way to represent the data when we are doing something like a 2D convolution, that needs spatial understanding of where the intermediate features are relative to each other. When we input  data into fully connected affine layers, however, we want each datapoint to be represented by a single vector -- it's no longer useful to segregate the different channels, rows, and columns of the data. So, we use a "Flatten" operation to collapse the C x H x W values per representation into a single long vector. The Flatten function below first reads in the N, C, H, and W values from a given batch of data, and then returns a "view" of that data. "View" is analogous to numpy's "reshape" method: it reshapes x's dimensions to be N x ??, where ?? is allowed to be anything (in this case, it will be C x H x W, but we don't need to specify that explicitly).

# %%
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size() # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

# %% [markdown]
# ### The example model itself
#
# The first step to training your own model is defining its architecture.
#
# Here's an example of a convolutional neural network defined in PyTorch -- try to understand what each line is doing, remembering that each layer is composed upon the previous layer. We haven't trained anything yet - that'll come next - for now, we want you to understand how everything gets set up.  nn.Sequential is a container which applies each layer
# one after the other.
#
# In that example, you see 2D convolutional layers (Conv2d), ReLU activations, and fully-connected layers (Linear). You also see the Cross-Entropy loss function, and the Adam optimizer being used.
#
# Make sure you understand why the parameters of the Linear layer are 5408 and 10.

# %%
# Here's where we define the architecture of the model... 
simple_model = nn.Sequential(
                nn.Conv2d(3, 32, kernel_size=7, stride=2),
                nn.ReLU(inplace=True),
                Flatten(), # see above for explanation
                nn.Linear(5408, 10), # affine layer
              )

# Set the type of all data in this model to be FloatTensor 
simple_model.type(dtype)

loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.Adam(simple_model.parameters(), lr=1e-2) # lr sets the learning rate of the optimizer

# %% [markdown]
# PyTorch supports many other layer types, loss functions, and optimizers - you will experiment with these next. Here's the official API documentation for these (if any of the parameters used above were unclear, this resource will also be helpful). One note: what we call in the class "spatial batch norm" is called "BatchNorm2D" in PyTorch.
#
# * Layers: http://pytorch.org/docs/nn.html
# * Activations: http://pytorch.org/docs/nn.html#non-linear-activations
# * Loss functions: http://pytorch.org/docs/nn.html#loss-functions
# * Optimizers: http://pytorch.org/docs/optim.html#algorithms

# %% [markdown]
# ## Training a specific model
#
# In this section, we're going to specify a model for you to construct. The goal here isn't to get good performance (that'll be next), but instead to get comfortable with understanding the PyTorch documentation and configuring your own model.
#
# Using the code provided above as guidance, and using the following PyTorch documentation, specify a model with the following architecture:
#
# * 7x7 Convolutional Layer with 32 filters and stride of 1
# * ReLU Activation Layer
# * Spatial Batch Normalization Layer
# * 2x2 Max Pooling layer with a stride of 2
# * Affine layer with 1024 output units
# * ReLU Activation Layer
# * Affine layer from 1024 input units to 10 outputs
#
# And finally, set up a **cross-entropy** loss function and the **RMSprop** learning rule.

# %%
fixed_model_base = nn.Sequential( # You fill this in!
    nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7, stride=1),
    nn.ReLU(inplace=True),
    nn.BatchNorm2d(num_features=32),
    nn.MaxPool2d(kernel_size=2,stride=2),
    Flatten(),
    nn.Linear(32*13*13, 1024), # affine layer
    nn.ReLU(inplace=True),
    nn.Linear(1024, 10)
            )

fixed_model = fixed_model_base.type(dtype)
loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.RMSprop(fixed_model.parameters(), lr=1e-2)

# %% [markdown]
# To make sure you're doing the right thing, use the following tool to check the dimensionality of your output (it should be 64 x 10, since our batches have size 64 and the output of the final affine layer should be 10, corresponding to our 10 classes):

# %%
## Now we're going to feed a random batch into the model you defined and make sure the output is the right size
x = torch.randn(64, 3, 32, 32).type(dtype)
x_var = Variable(x.type(dtype)) # Construct a PyTorch Variable out of your input data
ans = fixed_model(x_var)        # Feed it through the model! 

# Check to make sure what comes out of your model
# is the right dimensionality... this should be True
# if you've done everything correctly
np.array_equal(np.array(ans.size()), np.array([64, 10]))
# Out:
# True

# %% [markdown]
# ### GPU!
#
# Now, we're going to switch the dtype of the model and our data to the GPU-friendly tensors, and see what happens... everything is the same, except we are casting our model and input tensors as this new dtype instead of the old one.
#
# If this returns false, or otherwise fails in a not-graceful way (i.e., with some error message), you may not have an NVIDIA GPU available on your machine. If you're running locally, we recommend you switch to Google Cloud and follow the instructions to set up a GPU there. If you're already on Google Cloud, something is wrong -- make sure you followed the instructions on how to request and use a GPU on your instance. If you did, post on Piazza or come to Office Hours so we can help you debug.

# %%
# Verify that CUDA is properly configured and you have a GPU available

torch.cuda.is_available()
# Out:
# True

# %%
import copy
gpu_dtype = torch.cuda.FloatTensor

fixed_model_gpu = copy.deepcopy(fixed_model_base).type(gpu_dtype)

x_gpu = torch.randn(64, 3, 32, 32).type(gpu_dtype)
x_var_gpu = Variable(x.type(gpu_dtype)) # Construct a PyTorch Variable out of your input data
ans = fixed_model_gpu(x_var_gpu)        # Feed it through the model! 

# Check to make sure what comes out of your model
# is the right dimensionality... this should be True
# if you've done everything correctly
np.array_equal(np.array(ans.size()), np.array([64, 10]))
# Out:
# True

# %% [markdown]
# Run the following cell to evaluate the performance of the forward pass running on the CPU:

# %%
# %%timeit 
ans = fixed_model(x_var)
# Out:
# 10 loops, best of 3: 20.1 ms per loop

# %% [markdown]
# ... and now the GPU:

# %%
# %%timeit 
torch.cuda.synchronize() # Make sure there are no pending GPU computations
ans = fixed_model_gpu(x_var_gpu)        # Feed it through the model! 
torch.cuda.synchronize() # Make sure there are no pending GPU computations
# Out:
# 100 loops, best of 3: 3.24 ms per loop

# %% [markdown]
# You should observe that even a simple forward pass like this is significantly faster on the GPU. So for the rest of the assignment (and when you go train your models in assignment 3 and your project!), you should use the GPU datatype for your model and your tensors: as a reminder that is *torch.cuda.FloatTensor* (in our notebook here as *gpu_dtype*)

# %% [markdown]
# ### Train the model.
#
# Now that you've seen how to define a model and do a single forward pass of some data through it, let's  walk through how you'd actually train one whole epoch over your training data (using the simple_model we provided above).
#
# Make sure you understand how each PyTorch function used below corresponds to what you implemented in your custom neural network implementation.
#
# Note that because we are not resetting the weights anywhere below, if you run the cell multiple times, you are effectively training multiple epochs (so your performance should improve).
#
# First, set up an RMSprop optimizer (using a 1e-3 learning rate) and a cross-entropy loss function:

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.RMSprop(fixed_model_gpu.parameters(), lr=1e-3)

# %%
# This sets the model in "training" mode. This is relevant for some layers that may have different behavior
# in training mode vs testing mode, such as Dropout and BatchNorm. 
fixed_model_gpu.train()

# Load one batch at a time.
for t, (x, y) in enumerate(loader_train):
    x_var = Variable(x.type(gpu_dtype))
    y_var = Variable(y.type(gpu_dtype).long())

    # This is the forward pass: predict the scores for each class, for each x in the batch.
    scores = fixed_model_gpu(x_var)
    
    # Use the correct y values and the predicted y values to compute the loss.
    loss = loss_fn(scores, y_var)
    
    if (t + 1) % print_every == 0:
        print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

    # Zero out all of the gradients for the variables which the optimizer will update.
    optimizer.zero_grad()
    
    # This is the backwards pass: compute the gradient of the loss with respect to each 
    # parameter of the model.
    loss.backward()
    
    # Actually update the parameters of the model using the gradients computed by the backwards pass.
    optimizer.step()
# Out:
# t = 100, loss = 1.4583
# t = 200, loss = 1.5714
# t = 300, loss = 1.4150
# t = 400, loss = 1.3397
# t = 500, loss = 1.1939
# t = 600, loss = 1.4099
# t = 700, loss = 1.3418

# %% [markdown]
# Now you've seen how the training process works in PyTorch. To save you writing boilerplate code, we're providing the following helper functions to help you train for multiple epochs and check the accuracy of your model:

# %%
def train(model, loss_fn, optimizer, num_epochs = 1):
    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()
        for t, (x, y) in enumerate(loader_train):
            x_var = Variable(x.type(gpu_dtype))
            y_var = Variable(y.type(gpu_dtype).long())

            scores = model(x_var)
            
            loss = loss_fn(scores, y_var)
            if (t + 1) % print_every == 0:
                print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

def check_accuracy(model, loader):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for x, y in loader:
        x_var = Variable(x.type(gpu_dtype), volatile=True)

        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        num_correct += (preds == y).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %% [markdown]
# ### Check the accuracy of the model.
#
# Let's see the train and check_accuracy code in action -- feel free to use these methods when evaluating the models you develop below.
#
# You should get a training loss of around 1.2-1.4, and a validation accuracy of around 50-60%. As mentioned above, if you re-run the cells, you'll be training more epochs, so your performance will improve past these numbers.
#
# But don't worry about getting these numbers better -- this was just practice before you tackle designing your own model.

# %%
torch.cuda.random.manual_seed(12345)
fixed_model_gpu.apply(reset)
train(fixed_model_gpu, loss_fn, optimizer, num_epochs=1)
check_accuracy(fixed_model_gpu, loader_val)
# Out:
# Starting epoch 1 / 1
# t = 100, loss = 1.4143
# t = 200, loss = 1.6001
# t = 300, loss = 1.4367
# t = 400, loss = 1.2333
# t = 500, loss = 1.1317
# t = 600, loss = 1.3795
# t = 700, loss = 1.0912
# Checking accuracy on validation set
# Got 602 / 1000 correct (60.20)

# %% [markdown]
# ### Don't forget the validation set!
#
# And note that you can use the check_accuracy function to evaluate on either the test set or the validation set, by passing either **loader_test** or **loader_val** as the second argument to check_accuracy. You should not touch the test set until you have finished your architecture and hyperparameter tuning, and only run the test set once at the end to report a final value.

# %% [markdown]
# ## Train a _great_ model on CIFAR-10!
#
# Now it's your job to experiment with architectures, hyperparameters, loss functions, and optimizers to train a model that achieves **>=70%** accuracy on the CIFAR-10 **validation** set. You can use the check_accuracy and train functions from above.

# %% [markdown]
# ### Things you should try:
# - **Filter size**: Above we used 7x7; this makes pretty pictures but smaller filters may be more efficient
# - **Number of filters**: Above we used 32 filters. Do more or fewer do better?
# - **Pooling vs Strided Convolution**: Do you use max pooling or just stride convolutions?
# - **Batch normalization**: Try adding spatial batch normalization after convolution layers and vanilla batch normalization after affine layers. Do your networks train faster?
# - **Network architecture**: The network above has two layers of trainable parameters. Can you do better with a deep network? Good architectures to try include:
#     - [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [conv-relu-conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# - **Global Average Pooling**: Instead of flattening and then having multiple affine layers, perform convolutions until your image gets small (7x7 or so) and then perform an average pooling operation to get to a 1x1 image picture (1, 1 , Filter#), which is then reshaped into a (Filter#) vector. This is used in [Google's Inception Network](https://arxiv.org/abs/1512.00567) (See Table 1 for their architecture).
# - **Regularization**: Add l2 weight regularization, or perhaps use Dropout.
#
# ### Tips for training
# For each network architecture that you try, you should tune the learning rate and regularization strength. When doing this there are a couple important things to keep in mind:
#
# - If the parameters are working well, you should see improvement within a few hundred iterations
# - Remember the coarse-to-fine approach for hyperparameter tuning: start by testing a large range of hyperparameters for just a few training iterations to find the combinations of parameters that are working at all.
# - Once you have found some sets of parameters that seem to work, search more finely around these parameters. You may need to train for more epochs.
# - You should use the validation set for hyperparameter search, and save your test set for evaluating your architecture on the best parameters as selected by the validation set.
#
# ### Going above and beyond
# If you are feeling adventurous there are many other features you can implement to try and improve your performance. You are **not required** to implement any of these; however they would be good things to try for extra credit.
#
# - Alternative update steps: For the assignment we implemented SGD+momentum, RMSprop, and Adam; you could try alternatives like AdaGrad or AdaDelta.
# - Alternative activation functions such as leaky ReLU, parametric ReLU, ELU, or MaxOut.
# - Model ensembles
# - Data augmentation
# - New Architectures
#   - [ResNets](https://arxiv.org/abs/1512.03385) where the input from the previous layer is added to the output.
#   - [DenseNets](https://arxiv.org/abs/1608.06993) where inputs into previous layers are concatenated together.
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)
#
# If you do decide to implement something extra, clearly describe it in the "Extra Credit Description" cell below.
#
# ### What we expect
# At the very least, you should be able to train a ConvNet that gets at least 70% accuracy on the validation set. This is just a lower bound - if you are careful it should be possible to get accuracies much higher than that! Extra credit points will be awarded for particularly high-scoring models or unique approaches.
#
# You should use the space below to experiment and train your network.
#
# Have fun and happy training!

# %%
# Train your model here, and make sure the output of this cell is the accuracy of your best model on the 
# train, val, and test sets. Here's some code to get you started. The output of this cell should be the training
# and validation accuracy on your best model (measured by validation accuracy).

model = nn.Sequential(
    
    # conv-bn-relu-conv-bn-relu-pool
    nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(inplace=True),
    nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(2, stride=2),
    # conv-bn-relu-conv-bn-relu-pool
    nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(inplace=True),
    nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(2, stride=2),
    # conv-bn-relu-conv-bn-relu-pool
    nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
    nn.BatchNorm2d(128),
    nn.ReLU(inplace=True),
    nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
    nn.BatchNorm2d(128),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(2, stride=2),

    Flatten(),

    nn.Linear(4*4*128, 512),
    nn.BatchNorm1d(512),
    nn.ReLU(inplace=True),
    nn.Linear(512, 10),
            )

model.type(gpu_dtype)
loss_fn = nn.CrossEntropyLoss().type(gpu_dtype)
optimizer = optim.Adam(model.parameters(), lr = 1e-3)

train(model, loss_fn, optimizer, num_epochs=10)
check_accuracy(model, loader_val)
# Out:
# Starting epoch 1 / 10
# t = 100, loss = 1.2679
# t = 200, loss = 1.1517
# t = 300, loss = 0.9767
# t = 400, loss = 0.7684
# t = 500, loss = 0.8591
# t = 600, loss = 0.7601
# t = 700, loss = 1.1211
# Starting epoch 2 / 10
# t = 100, loss = 0.5703
# t = 200, loss = 0.7158
# t = 300, loss = 0.6594
# t = 400, loss = 0.6270
# t = 500, loss = 0.6834
# t = 600, loss = 0.5253
# t = 700, loss = 0.7479
# Starting epoch 3 / 10
# t = 100, loss = 0.4299
# t = 200, loss = 0.5189
# t = 300, loss = 0.4721
# t = 400, loss = 0.4772
# t = 500, loss = 0.4624
# t = 600, loss = 0.4179
# t = 700, loss = 0.6033
# Starting epoch 4 / 10
# t = 100, loss = 0.2684
# t = 200, loss = 0.3607
# t = 300, loss = 0.3180
# t = 400, loss = 0.3578
# t = 500, loss = 0.3437
# t = 600, loss = 0.2267
# t = 700, loss = 0.4116
# Starting epoch 5 / 10
# t = 100, loss = 0.1583
# t = 200, loss = 0.2614
# t = 300, loss = 0.2133
# t = 400, loss = 0.1924
# t = 500, loss = 0.2395
# t = 600, loss = 0.1733
# t = 700, loss = 0.2872
# Starting epoch 6 / 10
# t = 100, loss = 0.0989
# t = 200, loss = 0.1443
# t = 300, loss = 0.2139
# t = 400, loss = 0.1047
# t = 500, loss = 0.1273
# t = 600, loss = 0.0875
# t = 700, loss = 0.1662
# Starting epoch 7 / 10
# t = 100, loss = 0.1236
# t = 200, loss = 0.0920
# t = 300, loss = 0.0821
# t = 400, loss = 0.1007
# t = 500, loss = 0.1683
# t = 600, loss = 0.0960
# t = 700, loss = 0.0737
# Starting epoch 8 / 10
# t = 100, loss = 0.0685
# t = 200, loss = 0.0683
# t = 300, loss = 0.0557
# t = 400, loss = 0.2028
# t = 500, loss = 0.0419
# t = 600, loss = 0.0468
# t = 700, loss = 0.0764
# Starting epoch 9 / 10
# t = 100, loss = 0.0363
# t = 200, loss = 0.0454
# t = 300, loss = 0.0519
# t = 400, loss = 0.0291
# t = 500, loss = 0.2505
# t = 600, loss = 0.0863
# t = 700, loss = 0.1874
# Starting epoch 10 / 10
# t = 100, loss = 0.0539
# t = 200, loss = 0.0635
# t = 300, loss = 0.1113
# t = 400, loss = 0.0663
# t = 500, loss = 0.0583
# t = 600, loss = 0.0412
# t = 700, loss = 0.1498
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)

# %% [markdown]
# ### Describe what you did
#
# In the cell below you should write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network.

# %% [markdown]
# Tell us here!
#
# Apply the fine structure inspired by the homepage of Standford cs231n course:
# - [conv-batchnorm-relu-conv-batchnorm-relu-pool]x3 -> [affine]x1 -> [softmax]
#
# Besides, `Adam` is tested to be the best one. The kernel with size $3*3$ is better for our training sample with small size ($3*32*32$). And every batch normalization followed by the convolution layer help a lot towards **gradient vanishing & gradient explosion**.

# %% [markdown]
# ## Test set -- run this only once
#
# Now that we've gotten a result we're happy with, we test our final model on the test set (which you should store in best_model).  This would be the score we would achieve on a competition. Think about how this compares to your validation set accuracy.

# %%
best_model = model
check_accuracy(best_model, loader_test)
# Out:
# Checking accuracy on test set
# Got 8084 / 10000 correct (80.84)

# %% [markdown]
# ## Going further with PyTorch
#
# The next assignment will make heavy use of PyTorch. You might also find it useful for your projects.
#
# Here's a nice tutorial by Justin Johnson that shows off some of PyTorch's features, like dynamic graphs and custom NN modules: http://pytorch.org/tutorials/beginner/pytorch_with_examples.html
#
# If you're interested in reinforcement learning for your final project, this is a good (more advanced) DQN tutorial in PyTorch: http://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html

# %% [markdown]
# # Extra Credit Description

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import sampler

import torchvision.datasets as dset
import torchvision.transforms as T

import numpy as np

import timeit

class ChunkSampler(sampler.Sampler):
    """Samples elements sequentially from some offset. 
    Arguments:
        num_samples: # of desired datapoints
        start: offset where we should start selecting from
    """
    def __init__(self, num_samples, start = 0):
        self.num_samples = num_samples
        self.start = start

    def __iter__(self):
        return iter(range(self.start, self.start + self.num_samples))

    def __len__(self):
        return self.num_samples

NUM_TRAIN = 49000
NUM_VAL = 1000

cifar10_train = dset.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=T.ToTensor())
loader_train = DataLoader(cifar10_train, batch_size=128, sampler=ChunkSampler(NUM_TRAIN, 0))

cifar10_val = dset.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=T.ToTensor())
loader_val = DataLoader(cifar10_val, batch_size=128, sampler=ChunkSampler(NUM_VAL, NUM_TRAIN))

cifar10_test = dset.CIFAR10('./cs231n/datasets', train=False, download=True,
                          transform=T.ToTensor())
loader_test = DataLoader(cifar10_test, batch_size=128)

gpu_dtype = torch.cuda.FloatTensor
dtype = torch.FloatTensor # the CPU datatype

def train(model, loss_fn, optimizer, epoch):
    print('Starting epoch %d / %d' % (epoch + 1, 350))
    model.train()
    for t, (x, y) in enumerate(loader_train):
        x_var = Variable(x.type(gpu_dtype))
        y_var = Variable(y.type(gpu_dtype).long())

        scores = model(x_var)

        loss = loss_fn(scores, y_var)
        if (t + 1) % 100 == 0:
            print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

def check_accuracy(model, loader):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for x, y in loader:
        x_var = Variable(x.type(gpu_dtype), volatile=True)

        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        num_correct += (preds == y).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
    return acc
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
''' For extra credit, I'll implement a ResNet based on the paper of Kaiming, etc al.
    [1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun
    Deep Residual Learning for Image Recognition. arXiv:1512.03385
'''
import torch
import torch.nn as nn
import torch.nn.functional as F
import copy


class Block(nn.Module):
    ''' Basic shallow blocks for ResNet
    '''

    def __init__(self, in_channels, channels, stride):
        super(Block, self).__init__()
        
        self.path1 = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
        )

        if stride == 1:
            self.shortcut = False
        else:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, channels, kernel_size=1,
                          stride=stride, bias=False),
                nn.BatchNorm2d(channels)
            )
            
        self.path2 = nn.Sequential(
            nn.Conv2d(in_channels, channels, kernel_size=3,
                      stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(channels, channels, kernel_size=3,
                      stride=1, padding=1, bias=False),
            
        )

    def forward(self, x):
        out = self.path1(x)
        cut_in = self.shortcut(out) if self.shortcut else x
        out = self.path2(out)
        out += cut_in
        return out


class ResNet(nn.Module):
    def __init__(self, in_channels=3, num_classes=10):
        super(ResNet, self).__init__()

        self.block_size = 64  # Start from the 64 filters in the conv layer.

        self.conv1 = nn.Conv2d(
            in_channels, 64, kernel_size=3, stride=1, padding=1, bias=False)

        self.block1 = nn.Sequential(Block(64, 64, 1), Block(64, 64, 1))
        self.block2 = nn.Sequential(Block(64, 128, 2), Block(128, 128, 1))
        self.block3 = nn.Sequential(Block(128, 256, 2), Block(256, 256, 1))
        self.block4 = nn.Sequential(Block(256, 512, 2), Block(512, 512, 1))

        self.linear = nn.Linear(512, num_classes)

    def forward(self, x):
        out = self.conv1(x)
        out = self.block1(out)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
#         out = self.block4(self.block3(self.block2(self.block1(out))))
        out = F.avg_pool2d(out, 4)
    
        out = self.linear(out.view(out.size(0), -1))
        return out


model = ResNet().type(gpu_dtype)
# y = model(Variable(torch.randn(1, 3, 32, 32)))
# print(y.size())
loss_fn = nn.CrossEntropyLoss().type(gpu_dtype)
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)

# %%
## Continue from epoch 200 and re-store the best model
best_accuracy = [0]*10
best_models = [0]*10

for epoch in range(350):
    train(model, loss_fn, optimizer, epoch)
    accuracy = check_accuracy(model, loader_val)
    if epoch == 150:
        optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
    if epoch == 250:
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
        
    if epoch > 200:
        if accuracy > min(best_accuracy):
            target = best_accuracy.index(min(best_accuracy))
            best_accuracy[target] = accuracy
            best_models[target] = copy.deepcopy(model)
# Out:
# Starting epoch 1 / 350
# t = 100, loss = 1.7312
# t = 200, loss = 1.3235
# t = 300, loss = 1.2815
# Checking accuracy on validation set
# Got 450 / 1000 correct (45.00)
# Starting epoch 2 / 350
# t = 100, loss = 1.0769
# t = 200, loss = 0.8490
# t = 300, loss = 0.9838
# Checking accuracy on validation set
# Got 642 / 1000 correct (64.20)
# Starting epoch 3 / 350
# t = 100, loss = 0.8735
# t = 200, loss = 0.6890
# t = 300, loss = 0.7077
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
# Starting epoch 4 / 350
# t = 100, loss = 0.7013
# t = 200, loss = 0.5666
# t = 300, loss = 0.5479
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# Starting epoch 5 / 350
# t = 100, loss = 0.5938
# t = 200, loss = 0.4770
# t = 300, loss = 0.4597
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
# Starting epoch 6 / 350
# t = 100, loss = 0.5682
# t = 200, loss = 0.4925
# t = 300, loss = 0.3199
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
# Starting epoch 7 / 350
# t = 100, loss = 0.5173
# t = 200, loss = 0.4846
# t = 300, loss = 0.2766
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# Starting epoch 8 / 350
# t = 100, loss = 0.4464
# t = 200, loss = 0.3654
# t = 300, loss = 0.2845
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# Starting epoch 9 / 350
# t = 100, loss = 0.3953
# t = 200, loss = 0.4386
# t = 300, loss = 0.2117
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# Starting epoch 10 / 350
# t = 100, loss = 0.2620
# t = 200, loss = 0.3854
# t = 300, loss = 0.2914
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
# Starting epoch 11 / 350
# t = 100, loss = 0.2086
# t = 200, loss = 0.2924
# t = 300, loss = 0.1767
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
# Starting epoch 12 / 350
# t = 100, loss = 0.3005
# t = 200, loss = 0.4045
# t = 300, loss = 0.1439
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
# Starting epoch 13 / 350
# t = 100, loss = 0.2207
# t = 200, loss = 0.2296
# t = 300, loss = 0.1884
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# Starting epoch 14 / 350
# t = 100, loss = 0.3000
# t = 200, loss = 0.2854
# t = 300, loss = 0.2760
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# Starting epoch 15 / 350
# t = 100, loss = 0.1557
# t = 200, loss = 0.3206
# t = 300, loss = 0.1710
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# Starting epoch 16 / 350
# t = 100, loss = 0.2806
# t = 200, loss = 0.1888
# t = 300, loss = 0.0757
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
# Starting epoch 17 / 350
# t = 100, loss = 0.1799
# t = 200, loss = 0.3068
# t = 300, loss = 0.2320
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
# Starting epoch 18 / 350
# t = 100, loss = 0.1757
# t = 200, loss = 0.2593
# t = 300, loss = 0.2831
# Checking accuracy on validation set
# Got 691 / 1000 correct (69.10)
# Starting epoch 19 / 350
# t = 100, loss = 0.1632
# t = 200, loss = 0.3079
# t = 300, loss = 0.1039
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# Starting epoch 20 / 350
# t = 100, loss = 0.2048
# t = 200, loss = 0.1925
# t = 300, loss = 0.1436
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
# Starting epoch 21 / 350
# t = 100, loss = 0.1854
# t = 200, loss = 0.2113
# t = 300, loss = 0.0941
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# Starting epoch 22 / 350
# t = 100, loss = 0.1967
# t = 200, loss = 0.2088
# t = 300, loss = 0.2136
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
# Starting epoch 23 / 350
# t = 100, loss = 0.2009
# t = 200, loss = 0.1484
# t = 300, loss = 0.1155
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
# Starting epoch 24 / 350
# t = 100, loss = 0.1287
# t = 200, loss = 0.2385
# t = 300, loss = 0.1037
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
# Starting epoch 25 / 350
# t = 100, loss = 0.1478
# t = 200, loss = 0.1650
# t = 300, loss = 0.2090
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
# Starting epoch 26 / 350
# t = 100, loss = 0.1816
# t = 200, loss = 0.2598
# t = 300, loss = 0.2072
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# Starting epoch 27 / 350
# t = 100, loss = 0.1973
# t = 200, loss = 0.1754
# t = 300, loss = 0.1557
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# Starting epoch 28 / 350
# t = 100, loss = 0.2826
# t = 200, loss = 0.1375
# t = 300, loss = 0.2517
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
# Starting epoch 29 / 350
# t = 100, loss = 0.0925
# t = 200, loss = 0.3143
# t = 300, loss = 0.1519
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# Starting epoch 30 / 350
# t = 100, loss = 0.2399
# t = 200, loss = 0.2144
# t = 300, loss = 0.1287
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
# Starting epoch 31 / 350
# t = 100, loss = 0.2227
# t = 200, loss = 0.1906
# t = 300, loss = 0.2159
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
# Starting epoch 32 / 350
# t = 100, loss = 0.1580
# t = 200, loss = 0.1735
# t = 300, loss = 0.1412
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# Starting epoch 33 / 350
# t = 100, loss = 0.2481
# t = 200, loss = 0.1356
# t = 300, loss = 0.1760
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# Starting epoch 34 / 350
# t = 100, loss = 0.2362
# t = 200, loss = 0.3579
# t = 300, loss = 0.2382
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
# Starting epoch 35 / 350
# t = 100, loss = 0.1093
# t = 200, loss = 0.2252
# t = 300, loss = 0.1555
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# Starting epoch 36 / 350
# t = 100, loss = 0.1337
# t = 200, loss = 0.2130
# t = 300, loss = 0.1312
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# Starting epoch 37 / 350
# t = 100, loss = 0.1344
# t = 200, loss = 0.2660
# t = 300, loss = 0.1114
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# Starting epoch 38 / 350
# t = 100, loss = 0.1988
# t = 200, loss = 0.2708
# t = 300, loss = 0.1513
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
# Starting epoch 39 / 350
# t = 100, loss = 0.1458
# t = 200, loss = 0.1479
# t = 300, loss = 0.1693
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# Starting epoch 40 / 350
# t = 100, loss = 0.1377
# t = 200, loss = 0.2172
# t = 300, loss = 0.1942
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# Starting epoch 41 / 350
# t = 100, loss = 0.1759
# t = 200, loss = 0.2456
# t = 300, loss = 0.1724
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# Starting epoch 42 / 350
# t = 100, loss = 0.1677
# t = 200, loss = 0.2243
# t = 300, loss = 0.1167
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# Starting epoch 43 / 350
# t = 100, loss = 0.1235
# t = 200, loss = 0.1254
# t = 300, loss = 0.1617
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
# Starting epoch 44 / 350
# t = 100, loss = 0.2116
# t = 200, loss = 0.2783
# t = 300, loss = 0.1552
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
# Starting epoch 45 / 350
# t = 100, loss = 0.1026
# t = 200, loss = 0.1838
# t = 300, loss = 0.1432
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# Starting epoch 46 / 350
# t = 100, loss = 0.1239
# t = 200, loss = 0.1418
# t = 300, loss = 0.0915
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# Starting epoch 47 / 350
# t = 100, loss = 0.3628
# t = 200, loss = 0.3042
# t = 300, loss = 0.2071
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# Starting epoch 48 / 350
# t = 100, loss = 0.2045
# t = 200, loss = 0.1278
# t = 300, loss = 0.1675
# Checking accuracy on validation set
# Got 701 / 1000 correct (70.10)
# Starting epoch 49 / 350
# t = 100, loss = 0.1541
# t = 200, loss = 0.1653
# t = 300, loss = 0.0856
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# Starting epoch 50 / 350
# t = 100, loss = 0.1264
# t = 200, loss = 0.2217
# t = 300, loss = 0.1677
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# Starting epoch 51 / 350
# t = 100, loss = 0.1098
# t = 200, loss = 0.2071
# t = 300, loss = 0.1623
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
# Starting epoch 52 / 350
# t = 100, loss = 0.3685
# t = 200, loss = 0.1541
# t = 300, loss = 0.1685
# Checking accuracy on validation set
# Got 720 / 1000 correct (72.00)
# Starting epoch 53 / 350
# t = 100, loss = 0.1039
# t = 200, loss = 0.2145
# t = 300, loss = 0.1421
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# Starting epoch 54 / 350
# t = 100, loss = 0.1293
# t = 200, loss = 0.1633
# t = 300, loss = 0.1984
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# Starting epoch 55 / 350
# t = 100, loss = 0.2618
# t = 200, loss = 0.1958
# t = 300, loss = 0.0900
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# Starting epoch 56 / 350
# t = 100, loss = 0.1792
# t = 200, loss = 0.1805
# t = 300, loss = 0.2781
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# Starting epoch 57 / 350
# t = 100, loss = 0.1260
# t = 200, loss = 0.1750
# t = 300, loss = 0.1452
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# Starting epoch 58 / 350
# t = 100, loss = 0.1743
# t = 200, loss = 0.1598
# t = 300, loss = 0.2112
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# Starting epoch 59 / 350
# t = 100, loss = 0.1535
# t = 200, loss = 0.1847
# t = 300, loss = 0.1888
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# Starting epoch 60 / 350
# t = 100, loss = 0.1735
# t = 200, loss = 0.1639
# t = 300, loss = 0.1886
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# Starting epoch 61 / 350
# t = 100, loss = 0.2179
# t = 200, loss = 0.1528
# t = 300, loss = 0.0832
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# Starting epoch 62 / 350
# t = 100, loss = 0.0609
# t = 200, loss = 0.2226
# t = 300, loss = 0.1516
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# Starting epoch 63 / 350
# t = 100, loss = 0.1034
# t = 200, loss = 0.1493
# t = 300, loss = 0.2270
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# Starting epoch 64 / 350
# t = 100, loss = 0.1475
# t = 200, loss = 0.2016
# t = 300, loss = 0.0929
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
# Starting epoch 65 / 350
# t = 100, loss = 0.2643
# t = 200, loss = 0.1915
# t = 300, loss = 0.1476
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# Starting epoch 66 / 350
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-9a036a9e84b0> in <module>()
#       4
#       5 for epoch in range(350):
# ----> 6     train(model, loss_fn, optimizer, epoch)
#       7     accuracy = check_accuracy(model, loader_val)
#       8     if epoch == 150:
#
# <ipython-input-13-1e32f5fe3939> in train(model, loss_fn, optimizer, epoch)
#      51     model.train()
#      52     for t, (x, y) in enumerate(loader_train):
# ---> 53         x_var = Variable(x.type(gpu_dtype))
#      54         y_var = Variable(y.type(gpu_dtype).long())
#      55
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/_utils.py in _type(self, new_type, async)
#      32     if new_type.is_sparse:
#      33         raise RuntimeError("Cannot cast dense tensor to sparse tensor")
# ---> 34     return new_type(self.size()).copy_(self, async)
#      35
#      36
#
# KeyboardInterrupt:

# %%
## Interrupt it for quicker convergence
for epoch in range(130, 300):
    train(model, loss_fn, optimizer, epoch)
    accuracy = check_accuracy(model, loader_val)
    if epoch == 150:
        optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
    if epoch == 225:
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
        
    if epoch > 200:
        if accuracy > min(best_accuracy):
            target = best_accuracy.index(min(best_accuracy))
            best_accuracy[target] = accuracy
            best_models[target] = copy.deepcopy(model)
# Out:
# Starting epoch 131 / 350
# t = 100, loss = 0.1850
# t = 200, loss = 0.1388
# t = 300, loss = 0.1849
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# Starting epoch 132 / 350
# t = 100, loss = 0.1056
# t = 200, loss = 0.2428
# t = 300, loss = 0.1207
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
# Starting epoch 133 / 350
# t = 100, loss = 0.1554
# t = 200, loss = 0.1020
# t = 300, loss = 0.1669
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# Starting epoch 134 / 350
# t = 100, loss = 0.1608
# t = 200, loss = 0.2979
# t = 300, loss = 0.1943
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# Starting epoch 135 / 350
# t = 100, loss = 0.1398
# t = 200, loss = 0.1296
# t = 300, loss = 0.1403
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
# Starting epoch 136 / 350
# t = 100, loss = 0.1252
# t = 200, loss = 0.2250
# t = 300, loss = 0.1125
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
# Starting epoch 137 / 350
# t = 100, loss = 0.1983
# t = 200, loss = 0.1291
# t = 300, loss = 0.1507
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# Starting epoch 138 / 350
# t = 100, loss = 0.1359
# t = 200, loss = 0.1786
# t = 300, loss = 0.2408
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# Starting epoch 139 / 350
# t = 100, loss = 0.1832
# t = 200, loss = 0.1958
# t = 300, loss = 0.1283
# Checking accuracy on validation set
# Got 657 / 1000 correct (65.70)
# Starting epoch 140 / 350
# t = 100, loss = 0.1704
# t = 200, loss = 0.1992
# t = 300, loss = 0.1165
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
# Starting epoch 141 / 350
# t = 100, loss = 0.1155
# t = 200, loss = 0.1137
# t = 300, loss = 0.1254
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# Starting epoch 142 / 350
# t = 100, loss = 0.1570
# t = 200, loss = 0.1942
# t = 300, loss = 0.1519
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# Starting epoch 143 / 350
# t = 100, loss = 0.2341
# t = 200, loss = 0.1930
# t = 300, loss = 0.1358
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# Starting epoch 144 / 350
# t = 100, loss = 0.1603
# t = 200, loss = 0.2527
# t = 300, loss = 0.1756
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# Starting epoch 145 / 350
# t = 100, loss = 0.2475
# t = 200, loss = 0.1396
# t = 300, loss = 0.1624
# Checking accuracy on validation set
# Got 700 / 1000 correct (70.00)
# Starting epoch 146 / 350
# t = 100, loss = 0.1429
# t = 200, loss = 0.2566
# t = 300, loss = 0.1819
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# Starting epoch 147 / 350
# t = 100, loss = 0.1962
# t = 200, loss = 0.2236
# t = 300, loss = 0.1236
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# Starting epoch 148 / 350
# t = 100, loss = 0.1578
# t = 200, loss = 0.1532
# t = 300, loss = 0.1489
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# Starting epoch 149 / 350
# t = 100, loss = 0.1681
# t = 200, loss = 0.1474
# t = 300, loss = 0.1323
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
# Starting epoch 150 / 350
# t = 100, loss = 0.1950
# t = 200, loss = 0.2457
# t = 300, loss = 0.0938
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# Starting epoch 151 / 350
# t = 100, loss = 0.0937
# t = 200, loss = 0.1647
# t = 300, loss = 0.1685
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
# Starting epoch 152 / 350
# t = 100, loss = 0.0701
# t = 200, loss = 0.0658
# t = 300, loss = 0.0221
# Checking accuracy on validation set
# Got 885 / 1000 correct (88.50)
# Starting epoch 153 / 350
# t = 100, loss = 0.0100
# t = 200, loss = 0.0087
# t = 300, loss = 0.0053
# Checking accuracy on validation set
# Got 887 / 1000 correct (88.70)
# Starting epoch 154 / 350
# t = 100, loss = 0.0046
# t = 200, loss = 0.0045
# t = 300, loss = 0.0035
# Checking accuracy on validation set
# Got 891 / 1000 correct (89.10)
# Starting epoch 155 / 350
# t = 100, loss = 0.0033
# t = 200, loss = 0.0032
# t = 300, loss = 0.0027
# Checking accuracy on validation set
# Got 891 / 1000 correct (89.10)
# Starting epoch 156 / 350
# t = 100, loss = 0.0026
# t = 200, loss = 0.0026
# t = 300, loss = 0.0023
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 157 / 350
# t = 100, loss = 0.0023
# t = 200, loss = 0.0022
# t = 300, loss = 0.0021
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 158 / 350
# t = 100, loss = 0.0021
# t = 200, loss = 0.0020
# t = 300, loss = 0.0019
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 159 / 350
# t = 100, loss = 0.0019
# t = 200, loss = 0.0019
# t = 300, loss = 0.0018
# Checking accuracy on validation set
# Got 895 / 1000 correct (89.50)
# Starting epoch 160 / 350
# t = 100, loss = 0.0019
# t = 200, loss = 0.0018
# t = 300, loss = 0.0018
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 161 / 350
# t = 100, loss = 0.0018
# t = 200, loss = 0.0017
# t = 300, loss = 0.0017
# Checking accuracy on validation set
# Got 891 / 1000 correct (89.10)
# Starting epoch 162 / 350
# t = 100, loss = 0.0017
# t = 200, loss = 0.0016
# t = 300, loss = 0.0017
# Checking accuracy on validation set
# Got 895 / 1000 correct (89.50)
# Starting epoch 163 / 350
# t = 100, loss = 0.0017
# t = 200, loss = 0.0016
# t = 300, loss = 0.0017
# Checking accuracy on validation set
# Got 895 / 1000 correct (89.50)
# Starting epoch 164 / 350
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-134037e68472> in <module>()
#       1 ## Interrupt it for quicker convergence
#       2 for epoch in range(130, 300):
# ----> 3     train(model, loss_fn, optimizer, epoch)
#       4     accuracy = check_accuracy(model, loader_val)
#       5     if epoch == 150:
#
# <ipython-input-13-1e32f5fe3939> in train(model, loss_fn, optimizer, epoch)
#      50     print('Starting epoch %d / %d' % (epoch + 1, 350))
#      51     model.train()
# ---> 52     for t, (x, y) in enumerate(loader_train):
#      53         x_var = Variable(x.type(gpu_dtype))
#      54         y_var = Variable(y.type(gpu_dtype).long())
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     150                 raise StopIteration
#     151             indices = self._next_indices()
# --> 152             batch = self.collate_fn([self.dataset[i] for i in indices])
#     153             if self.pin_memory:
#     154                 batch = pin_memory_batch(batch)
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     150                 raise StopIteration
#     151             indices = self._next_indices()
# --> 152             batch = self.collate_fn([self.dataset[i] for i in indices])
#     153             if self.pin_memory:
#     154                 batch = pin_memory_batch(batch)
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#      97
#      98         if self.transform is not None:
# ---> 99             img = self.transform(img)
#     100
#     101         if self.target_transform is not None:
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torchvision/transforms.py in __call__(self, pic)
#      61         img = img.transpose(0, 1).transpose(0, 2).contiguous()
#      62         if isinstance(img, torch.ByteTensor):
# ---> 63             return img.float().div(255)
#      64         else:
#      65             return img
#
# KeyboardInterrupt:

# %%
## Interrupt it for quicker convergence
for epoch in range(200, 275):
    train(model, loss_fn, optimizer, epoch)
    accuracy = check_accuracy(model, loader_val)
    if epoch == 150:
        optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
    if epoch == 225:
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
        
    if epoch > 200:
        if accuracy > min(best_accuracy):
            target = best_accuracy.index(min(best_accuracy))
            best_accuracy[target] = accuracy
            best_models[target] = copy.deepcopy(model)
# Out:
# Starting epoch 201 / 350
# t = 100, loss = 0.0017
# t = 200, loss = 0.0015
# t = 300, loss = 0.0017
# Checking accuracy on validation set
# Got 897 / 1000 correct (89.70)
# Starting epoch 202 / 350
# t = 100, loss = 0.0016
# t = 200, loss = 0.0015
# t = 300, loss = 0.0017
# Checking accuracy on validation set
# Got 897 / 1000 correct (89.70)
# Starting epoch 203 / 350
# t = 100, loss = 0.0016
# t = 200, loss = 0.0014
# t = 300, loss = 0.0016
# Checking accuracy on validation set
# Got 898 / 1000 correct (89.80)
# Starting epoch 204 / 350
# t = 100, loss = 0.0016
# t = 200, loss = 0.0014
# t = 300, loss = 0.0016
# Checking accuracy on validation set
# Got 898 / 1000 correct (89.80)
# Starting epoch 205 / 350
# t = 100, loss = 0.0015
# t = 200, loss = 0.0014
# t = 300, loss = 0.0016
# Checking accuracy on validation set
# Got 899 / 1000 correct (89.90)
# Starting epoch 206 / 350
# t = 100, loss = 0.0015
# t = 200, loss = 0.0013
# t = 300, loss = 0.0016
# Checking accuracy on validation set
# Got 898 / 1000 correct (89.80)
# Starting epoch 207 / 350
# t = 100, loss = 0.0015
# t = 200, loss = 0.0013
# t = 300, loss = 0.0016
# Checking accuracy on validation set
# Got 898 / 1000 correct (89.80)
# Starting epoch 208 / 350
# t = 100, loss = 0.0015
# t = 200, loss = 0.0013
# t = 300, loss = 0.0015
# Checking accuracy on validation set
# Got 899 / 1000 correct (89.90)
# Starting epoch 209 / 350
# t = 100, loss = 0.0015
# t = 200, loss = 0.0013
# t = 300, loss = 0.0015
# Checking accuracy on validation set
# Got 898 / 1000 correct (89.80)
# Starting epoch 210 / 350
# t = 100, loss = 0.0014
# t = 200, loss = 0.0012
# t = 300, loss = 0.0015
# Checking accuracy on validation set
# Got 897 / 1000 correct (89.70)
# Starting epoch 211 / 350
# t = 100, loss = 0.0014
# t = 200, loss = 0.0012
# t = 300, loss = 0.0015
# Checking accuracy on validation set
# Got 896 / 1000 correct (89.60)
# Starting epoch 212 / 350
# t = 100, loss = 0.0014
# t = 200, loss = 0.0012
# t = 300, loss = 0.0015
# Checking accuracy on validation set
# Got 896 / 1000 correct (89.60)
# Starting epoch 213 / 350
# t = 100, loss = 0.0014
# t = 200, loss = 0.0011
# t = 300, loss = 0.0014
# Checking accuracy on validation set
# Got 896 / 1000 correct (89.60)
# Starting epoch 214 / 350
# t = 100, loss = 0.0014
# t = 200, loss = 0.0011
# t = 300, loss = 0.0014
# Checking accuracy on validation set
# Got 896 / 1000 correct (89.60)
# Starting epoch 215 / 350
# t = 100, loss = 0.0013
# t = 200, loss = 0.0011
# t = 300, loss = 0.0014
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 216 / 350
# t = 100, loss = 0.0013
# t = 200, loss = 0.0011
# t = 300, loss = 0.0014
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 217 / 350
# t = 100, loss = 0.0013
# t = 200, loss = 0.0010
# t = 300, loss = 0.0013
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 218 / 350
# t = 100, loss = 0.0013
# t = 200, loss = 0.0010
# t = 300, loss = 0.0013
# Checking accuracy on validation set
# Got 895 / 1000 correct (89.50)
# Starting epoch 219 / 350
# t = 100, loss = 0.0013
# t = 200, loss = 0.0010
# t = 300, loss = 0.0013
# Checking accuracy on validation set
# Got 895 / 1000 correct (89.50)
# Starting epoch 220 / 350
# t = 100, loss = 0.0012
# t = 200, loss = 0.0010
# t = 300, loss = 0.0012
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 221 / 350
# t = 100, loss = 0.0012
# t = 200, loss = 0.0010
# t = 300, loss = 0.0012
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 222 / 350
# t = 100, loss = 0.0012
# t = 200, loss = 0.0009
# t = 300, loss = 0.0012
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 223 / 350
# t = 100, loss = 0.0012
# t = 200, loss = 0.0009
# t = 300, loss = 0.0012
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 224 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0009
# t = 300, loss = 0.0011
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 225 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0009
# t = 300, loss = 0.0011
# Checking accuracy on validation set
# Got 895 / 1000 correct (89.50)
# Starting epoch 226 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0009
# t = 300, loss = 0.0011
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 227 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 228 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 229 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 230 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 231 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 232 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 233 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 234 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 235 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 236 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 237 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 238 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 239 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 240 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 241 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 242 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 243 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 244 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 245 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 246 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 247 / 350
# t = 100, loss = 0.0011
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 248 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 249 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 250 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 251 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 252 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 253 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 254 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 894 / 1000 correct (89.40)
# Starting epoch 255 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 256 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 257 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 258 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 259 / 350
# t = 100, loss = 0.0010
# t = 200, loss = 0.0008
# t = 300, loss = 0.0010
# Checking accuracy on validation set
# Got 893 / 1000 correct (89.30)
# Starting epoch 260 / 350
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-94af0d778000> in <module>()
#       1 ## Interrupt it for quicker convergence
#       2 for epoch in range(200, 275):
# ----> 3     train(model, loss_fn, optimizer, epoch)
#       4     accuracy = check_accuracy(model, loader_val)
#       5     if epoch == 150:
#
# <ipython-input-13-1e32f5fe3939> in train(model, loss_fn, optimizer, epoch)
#      50     print('Starting epoch %d / %d' % (epoch + 1, 350))
#      51     model.train()
# ---> 52     for t, (x, y) in enumerate(loader_train):
#      53         x_var = Variable(x.type(gpu_dtype))
#      54         y_var = Variable(y.type(gpu_dtype).long())
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     150                 raise StopIteration
#     151             indices = self._next_indices()
# --> 152             batch = self.collate_fn([self.dataset[i] for i in indices])
#     153             if self.pin_memory:
#     154                 batch = pin_memory_batch(batch)
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     150                 raise StopIteration
#     151             indices = self._next_indices()
# --> 152             batch = self.collate_fn([self.dataset[i] for i in indices])
#     153             if self.pin_memory:
#     154                 batch = pin_memory_batch(batch)
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#      97
#      98         if self.transform is not None:
# ---> 99             img = self.transform(img)
#     100
#     101         if self.target_transform is not None:
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torchvision/transforms.py in __call__(self, pic)
#      48             img = torch.from_numpy(np.array(pic, np.int16, copy=False))
#      49         else:
# ---> 50             img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
#      51         # PIL image mode: 1, L, P, I, F, RGB, YCbCr, RGBA, CMYK
#      52         if pic.mode == 'YCbCr':
#
# KeyboardInterrupt:

# %%
## I interrupt it since it has overfitted
for model in best_models:
    check_accuracy(model, loader_test)
# Out:
# Checking accuracy on test set
# Got 8710 / 10000 correct (87.10)
# Checking accuracy on test set
# Got 8711 / 10000 correct (87.11)
# Checking accuracy on test set
# Got 8717 / 10000 correct (87.17)
# Checking accuracy on test set
# Got 8712 / 10000 correct (87.12)
# Checking accuracy on test set
# Got 8714 / 10000 correct (87.14)
# Checking accuracy on test set
# Got 8716 / 10000 correct (87.16)
# Checking accuracy on test set
# Got 8715 / 10000 correct (87.15)
# Checking accuracy on test set
# Got 8719 / 10000 correct (87.19)
# Checking accuracy on test set
# Got 8723 / 10000 correct (87.23)
# Checking accuracy on test set
# Got 8726 / 10000 correct (87.26)

# %% [markdown]
# I just implemented a reletively shallow ResNet, and it achieves approximately **90%** validation accuracy in our test data, which shows the great design of it. There is no doubt it;ll be better in fine tuning (the conputation capacity is the main constraint for me).
# Please tell me what confused you in my homework, and I do think my oridinary CNN is also well-structured with 82% accuracy. Any bonus is welcome.
